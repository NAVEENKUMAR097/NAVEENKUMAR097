# %% [markdown]
# <a href="https://colab.research.google.com/github/NAVEENKUMAR097/NAVEENKUMAR097/blob/main/Copy_of_SVM_Assignment14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Social_Network_Ads.csv

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **Importing the dataset**

# %%
data = pd.read_csv('/content/Social_Network_Ads.csv')
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [markdown]
# **Splitting the dataset into the Training set and Test set**

# %%
x = data.iloc[:,2:4]
y = data.iloc[:,-1]
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %% [markdown]
# **Feature Scaling**

# %%
stand = StandardScaler()
x_train = stand.fit_transform(x_train)
x_test = stand.fit_transform(x_test)
x_train
# Out:
# array([[ 0.71302525, -1.07225024],
#        [-1.59558939,  0.56429897],
#        [ 2.1559094 ,  0.97343627],
#        [ 1.67494802, -0.86768158],
#        [ 0.13587159,  1.55791813],
#        [-0.05651296,  2.25929636],
#        [-0.63366662, -0.31242382],
#        [-1.11462801,  0.33050623],
#        [-1.01843573,  0.79809171],
#        [ 0.71302525, -0.69233703],
#        [ 1.19398663, -0.95535386],
#        [ 1.00160208, -0.98457796],
#        [ 0.42444842, -0.13707926],
#        [-0.05651296, -0.4000961 ],
#        [ 1.19398663,  0.56429897],
#        [-0.24889752, -0.72156112],
#        [-0.7298589 , -0.19552745],
#        [-1.01843573, -0.34164791],
#        [ 1.67494802,  1.79171087],
#        [-1.30701256, -0.4000961 ],
#        [-1.11462801,  1.44102176],
#        [ 0.03967931,  0.06748939],
#        [ 1.38637119, -0.89690568],
#        [ 0.61683297, -0.86768158],
#        [-0.63366662,  0.21360985],
#        [-0.05651296, -0.45854428],
#        [ 1.09779436,  0.50585078],
# ...

# %% [markdown]
# **Fitting SVM to the Training set**

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# **Predicting the Test set results**

# %%
y_pr = svm.predict(x_test)
score = svm.score(x_test,y_test)
score
# Out:
# 0.95

# %% [markdown]
# **Making the Confusion Matrix**

# %%
confu = confusion_matrix(y_test,y_pr)
confu
# Out:
# array([[52,  2],
#        [ 2, 24]])

# %% [markdown]
# **Visualising the Training set results**

# %% [markdown]
# **Visualising the Test set results**
